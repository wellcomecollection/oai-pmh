# %% [markdown]
# ## Prerequisites
# * Ensure this repository's virtual environment is active (or run via `uv run`).
# * The `oai_pmh_client` package must be importable from `src/`.
# * Network access is required to reach the public arXiv OAI-PMH endpoint.

# %% [markdown]
# ## Installing `oai_pmh_client` from this repo
# Run one of the following commands from the repository root so the notebook can import `oai_pmh_client`:
#
# ```bash
# uv pip install -e .
# ```
#
# or, if you're already inside the project virtual environment,
#
# ```bash
# pip install -e .
# ```
#
# After installing once, restart the notebook kernel so the import path is refreshed.

# %%
from __future__ import annotations

from datetime import datetime, timedelta, timezone
from itertools import islice

from oai_pmh_client import OAIClient

# %%
BASE_URL = "https://export.arxiv.org/oai2"
METADATA_PREFIX = "oai_dc"  # arXiv also supports e.g. oai_dc, arXivRaw, etc.
MAX_RESULTS = 100  # safety cap so we don't page through everything at once
LOOKBACK_HOURS = 24

client = OAIClient(base_url=BASE_URL, datestamp_granularity="YYYY-MM-DD")
print(f"Configured OAI client for {BASE_URL}")
# Out:
# Configured OAI client for https://export.arxiv.org/oai2

# %%
window_end = datetime.now(timezone.utc)
window_start = window_end - timedelta(hours=LOOKBACK_HOURS)
print("Harvest window:", window_start.isoformat(), "->", window_end.isoformat())

records = []
iterator = client.list_records(
    metadata_prefix=METADATA_PREFIX,
    from_date=window_start,
    until_date=window_end,
    set_spec=None,
)

for record in islice(iterator, MAX_RESULTS):
    header = record.header
    identifier = header.identifier if header else "(no identifier)"
    datestamp = header.datestamp.isoformat() if header and header.datestamp else None
    deleted = header.is_deleted if header else False
    records.append(
        {
            "identifier": identifier,
            "datestamp": datestamp,
            "deleted": deleted,
        }
    )

print(f"Fetched {len(records)} record(s) (capped at {MAX_RESULTS}).")
# Out:
# Harvest window: 2025-11-17T07:56:27.932925+00:00 -> 2025-11-18T07:56:27.932925+00:00
# Fetched 100 record(s) (capped at 100).

# %%
if not records:
    print("No changed records found in the chosen window.")
else:
    for entry in records:
        state = "DELETED" if entry["deleted"] else "ACTIVE"
        print(f"{entry['datestamp']} | {state} | {entry['identifier']}")

    print("---")
    print(
        f"Displayed {len(records)} changed record(s) from the last {LOOKBACK_HOURS} hours."
    )
# Out:
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:1304.0833
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:1411.7677
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:1709.01928
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:1906.08243
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:1910.07653
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2002.03303
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2012.05212
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2012.15281
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2101.08802
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2102.02115
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2105.11419
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2107.01950
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2107.09348
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2201.08443
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2201.12577
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2203.06438
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2203.16435
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2205.00223
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2206.03863
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2206.10431
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2206.11948
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2206.13646
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2207.00077
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2207.03400
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2208.03273
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2208.11178
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2209.15409
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2211.00636
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2211.02212
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2212.07337
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2301.00862
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2301.06129
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2301.06142
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2301.08178
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2301.11515
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2302.14361
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2303.02796
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2303.03782
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2304.13925
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2305.02060
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2305.06315
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2305.10468
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2305.19112
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2306.03997
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2306.09010
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2307.16117
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2308.01174
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2309.12067
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2309.15942
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2310.01363
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2310.10070
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2311.02960
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2311.15257
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2311.17663
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2312.00274
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2312.01253
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2312.08467
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2312.08527
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2312.09114
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2312.12121
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2312.13750
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2312.15413
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2312.17315
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2401.00614
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2401.05532
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2401.08070
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2401.10960
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2401.11323
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2401.15789
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2402.04748
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2402.11608
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2402.12565
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2402.14183
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2402.14631
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2402.19088
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2403.01994
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2403.02912
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2403.03048
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2403.03169
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2403.03259
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2403.07370
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2403.10568
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2403.16684
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2403.18445
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2404.06745
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2404.07630
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2404.08773
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2404.12304
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2404.13063
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2404.14228
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2404.14940
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2404.15415
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2404.17934
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2405.04370
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2405.05710
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2405.08151
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2405.08361
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2405.11375
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2405.15033
# 2025-11-17T00:00:00 | ACTIVE | oai:arXiv.org:2405.19212
# ---
# Displayed 100 changed record(s) from the last 24 hours.
